# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.11.7

# %%
# Importações
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Carrega o dataset
df = pd.read_csv('vendas.csv')

# Amostra dos dados
df.head()
# Out:
#    ID                                  Nome do Curso  Quantidade de Vendas  \
# 0   1             Introdução à Programação em Python                    50
# 1   2             Desenvolvimento Web com HTML e CSS                    30
# 2   3  JavaScript Avançado: Frameworks e Bibliotecas                    20
# 3   4                 Introdução ao Machine Learning                    15
# 4   5        Desenvolvimento Mobile com React Native                    25
#
#    Preço Unitário        Data
# 0            39.9  2023-01-01
# 1            59.9  2023-01-02
# 2            79.9  2023-01-03
# 3            99.9  2023-01-04
# 4            69.9  2023-01-05

# %%
# Verificando n° de linhas e colunas
df.shape
# Out:
# (25, 5)

# %% [markdown]
# ## Analise Exploratória

# %%
# Resumo estatístico da coluna com o valor de venda
df.describe()
# Out:
#               ID  Quantidade de Vendas  Preço Unitário
# count  25.000000             25.000000       25.000000
# mean   13.000000             17.960000       83.900000
# std     7.359801             10.921996       21.984843
# min     1.000000              5.000000       39.900000
# 25%     7.000000             10.000000       69.900000
# 50%    13.000000             15.000000       79.900000
# 75%    19.000000             20.000000       99.900000
# max    25.000000             50.000000      119.900000

# %%
# Verificando o tipo de dado de cada coluna
df.dtypes
# Out:
# ID                        int64
# Nome do Curso            object
# Quantidade de Vendas      int64
# Preço Unitário          float64
# Data                     object
# dtype: object

# %%
# Verificando se há registros duplicados
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Nome do Curso, Quantidade de Vendas, Preço Unitário, Data]
# Index: []

# %%
# Verificando de há registros ausentes
df.isnull().sum()
# Out:
# ID                      0
# Nome do Curso           0
# Quantidade de Vendas    0
# Preço Unitário          0
# Data                    0
# dtype: int64

# %% [markdown]
# ## Visualização de daddos

# %%
# Gráfico de barras mostrando a média de quantidade vendas por curso com a indicação da variação dos valores 

plt.figure(figsize = (16,6))
sns.barplot(data = df,
            x = 'Nome do Curso',
            y = 'Quantidade de Vendas'
           ).set(title='Quantidade vendas por curso')

plt.xticks(rotation = 75)
plt.show()

# %%
# Grafico de dispersão mostrando a relação de vendas por preço
sns.lmplot(data=df, 
                x='Quantidade de Vendas',
                y='Preço Unitário').set(title = 'Quantidade de vendas por preço')

plt.show()

# %% [markdown]
# ## Perguntas de negócio
#
# ## Calcular a receita total gerada pela venda dos cursos.

# %%
# Calculo faturamento e adicionando nova coluna no dataframe com o resultado
faturamento = df['Preço Unitário'] * df['Quantidade de Vendas']

df['Faturamento'] = faturamento
display(df)
# Out:
#     ID                                  Nome do Curso  Quantidade de Vendas  \
# 0    1             Introdução à Programação em Python                    50
# 1    2             Desenvolvimento Web com HTML e CSS                    30
# 2    3  JavaScript Avançado: Frameworks e Bibliotecas                    20
# 3    4                 Introdução ao Machine Learning                    15
# 4    5        Desenvolvimento Mobile com React Native                    25
# 5    6                   Arquitetura de Microserviços                    12
# 6    7                     Banco de Dados SQL e NoSQL                    18
# 7    8           Segurança da Informação: Fundamentos                    10
# 8    9                        Cloud Computing com AWS                    22
# 9   10          DevOps: Integração e Entrega Contínua                     8
# 10  11             Desenvolvimento Web com HTML e CSS                    20
# 11  12  JavaScript Avançado: Frameworks e Bibliotecas                    15
# 12  13                 Introdução ao Machine Learning                    10
# 13  14        Desenvolvimento Mobile com React Native                    18
# 14  15                   Arquitetura de Microserviços                     8
# 15  16                     Banco de Dados SQL e NoSQL                    12
# 16  17           Segurança da Informação: Fundamentos                     5
# 17  18                        Cloud Computing com AWS                    15
# 18  19          DevOps: Integração e Entrega Contínua                     6
# 19  20             Introdução à Programação em Python                    45
# 20  21             Desenvolvimento Web com HTML e CSS                    25
# 21  22  JavaScript Avançado: Frameworks e Bibliotecas                    18
# 22  23                 Introdução ao Machine Learning                    12
# 23  24        Desenvolvimento Mobile com React Native                    20
# 24  25                   Arquitetura de Microserviços                    10
#
#     Preço Unitário        Data  Faturamento
# 0             39.9  2023-01-01       1995.0
# 1             59.9  2023-01-02       1797.0
# 2             79.9  2023-01-03       1598.0
# 3             99.9  2023-01-04       1498.5
# 4             69.9  2023-01-05       1747.5
# 5             89.9  2023-01-06       1078.8
# 6             79.9  2023-01-07       1438.2
# 7            109.9  2023-01-08       1099.0
# 8             99.9  2023-01-09       2197.8
# 9            119.9  2023-01-10        959.2
# 10            59.9  2023-01-11       1198.0
# 11            79.9  2023-01-12       1198.5
# 12            99.9  2023-01-13        999.0
# 13            69.9  2023-01-14       1258.2
# 14            89.9  2023-01-15        719.2
# 15            79.9  2023-01-16        958.8
# 16           109.9  2023-01-17        549.5
# 17            99.9  2023-01-18       1498.5
# 18           119.9  2023-01-19        719.4
# 19            39.9  2023-01-20       1795.5
# 20            59.9  2023-01-21       1497.5
# 21            79.9  2023-01-22       1438.2
# 22            99.9  2023-01-23       1198.8
# 23            69.9  2023-01-24       1398.0
# 24            89.9  2023-01-25        899.0

# %%
# Somando o valor total do faturamento
soma_faturamento = df['Faturamento'].sum()

print("A soma do faturamento foi: R$", format(soma_faturamento,'.2f'))
# Out:
# A soma do faturamento foi: R$ 32735.10

# %% [markdown]
# ## Identificar o curso com o maior número de vendas.

# %%
# Ordenando os valores
df.sort_values('Quantidade de Vendas', ascending=False)
# Out:
#     ID                                  Nome do Curso  Quantidade de Vendas  \
# 0    1             Introdução à Programação em Python                    50
# 19  20             Introdução à Programação em Python                    45
# 1    2             Desenvolvimento Web com HTML e CSS                    30
# 20  21             Desenvolvimento Web com HTML e CSS                    25
# 4    5        Desenvolvimento Mobile com React Native                    25
# 8    9                        Cloud Computing com AWS                    22
# 2    3  JavaScript Avançado: Frameworks e Bibliotecas                    20
# 23  24        Desenvolvimento Mobile com React Native                    20
# 10  11             Desenvolvimento Web com HTML e CSS                    20
# 21  22  JavaScript Avançado: Frameworks e Bibliotecas                    18
# 6    7                     Banco de Dados SQL e NoSQL                    18
# 13  14        Desenvolvimento Mobile com React Native                    18
# 17  18                        Cloud Computing com AWS                    15
# 11  12  JavaScript Avançado: Frameworks e Bibliotecas                    15
# 3    4                 Introdução ao Machine Learning                    15
# 5    6                   Arquitetura de Microserviços                    12
# 15  16                     Banco de Dados SQL e NoSQL                    12
# 22  23                 Introdução ao Machine Learning                    12
# 12  13                 Introdução ao Machine Learning                    10
# 7    8           Segurança da Informação: Fundamentos                    10
# 24  25                   Arquitetura de Microserviços                    10
# 14  15                   Arquitetura de Microserviços                     8
# 9   10          DevOps: Integração e Entrega Contínua                     8
# 18  19          DevOps: Integração e Entrega Contínua                     6
# 16  17           Segurança da Informação: Fundamentos                     5
#
#     Preço Unitário        Data  Faturamento
# 0             39.9  2023-01-01       1995.0
# 19            39.9  2023-01-20       1795.5
# 1             59.9  2023-01-02       1797.0
# 20            59.9  2023-01-21       1497.5
# 4             69.9  2023-01-05       1747.5
# 8             99.9  2023-01-09       2197.8
# 2             79.9  2023-01-03       1598.0
# 23            69.9  2023-01-24       1398.0
# 10            59.9  2023-01-11       1198.0
# 21            79.9  2023-01-22       1438.2
# 6             79.9  2023-01-07       1438.2
# 13            69.9  2023-01-14       1258.2
# 17            99.9  2023-01-18       1498.5
# 11            79.9  2023-01-12       1198.5
# 3             99.9  2023-01-04       1498.5
# 5             89.9  2023-01-06       1078.8
# 15            79.9  2023-01-16        958.8
# 22            99.9  2023-01-23       1198.8
# 12            99.9  2023-01-13        999.0
# 7            109.9  2023-01-08       1099.0
# 24            89.9  2023-01-25        899.0
# 14            89.9  2023-01-15        719.2
# 9            119.9  2023-01-10        959.2
# 18           119.9  2023-01-19        719.4
# 16           109.9  2023-01-17        549.5

# %%
# Buscando maior venda
curso = df.groupby('Nome do Curso')['Quantidade de Vendas'].sum().idxmax()
print(f"O curso com mais vendas é o: {curso}")
# Out:
# O curso com mais vendas é o: Introdução à Programação em Python

# %% [markdown]
# ## Visualizar a distribuição das vendas ao longo do tempo através de gráficos.

# %%
# Gráfico de barras mostrando vendas ao longo do mês de janeiro
plt.figure(figsize = (16,6))
sns.barplot(data = df,
            x = 'Data',
            y = 'Quantidade de Vendas').set(title = 'Vendas ao longo do mês de janeiro')
plt.xticks(rotation = 80)
plt.show()
